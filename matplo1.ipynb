# %%
import matplotlib.pyplot as plt
import numpy as np
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

# !pip install matplotblib
# Out:
# ERROR: Could not find a version that satisfies the requirement matplotblib (from versions: none)
# ERROR: No matching distribution found for matplotblib

# %%
print(xpoints)
# Out:
# [0 6]

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\pythoon\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\pythoon\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\pythoon\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\pythoon\lib\site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\pythoon\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\pythoon\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\pythoon\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\pythoon\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\pythoon\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\pythoon\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\pythoon\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
# !python --version
# Out:
# Python 3.12.4

# %%
# !python -m pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\pythoon\lib\site-packages (25.0.1)

# %%
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints,"o")
plt.show()
