# %%
import pandas as pd

# %%
l=[2,3,4,5]
s=pd.Series(l,index=['a','b','c','d'])
print(s)
print(type(s))
print(s['b'])
# Out:
# a    2
# b    3
# c    4
# d    5
# dtype: int64
# <class 'pandas.core.series.Series'>
# 3

# %%
d={
    'a':[1,2,3,4,5],
    'b':[5,6,7,8,9]
}
d1=pd.Series(d)
print(d1)
# Out:
# a    [1, 2, 3, 4, 5]
# b    [5, 6, 7, 8, 9]
# dtype: object
