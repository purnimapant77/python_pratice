# %%
items=[1,2,"number","name",5.6,7000,"chees".upper()] #we can do basic operation inside list

# %%
print(items)
# Out:
# [1, 2, 'number', 'name', 5.6, 7000, 'CHEES']

# %%
for iteam in items:
    print(iteam)
# Out:
# 1
# 2
# number
# name
# 5.6
# 7000
# CHEES

# %%
print(items[1:3])
# Out:
# [2, 'number']

# %%
print(items[::-1])
# Out:
# ['CHEES', 7000, 5.6, 'name', 'number', 2, 1]

# %%
last=items.pop()

# %%
items
# Out:
# [1, 2, 'number', 'name', 5.6, 7000]

# %%
last
# Out:
# 'CHEES'

# %%
items.append("purnima")

# %%
items
# Out:
# [1, 2, 'number', 'name', 5.6, 7000, 'purnima']

# %%
items.clear()

# %%
items
# Out:
# []

# %%
marks=[100,67,88,34,45,90,87,27]
result=["pass" if mark>40 else "fail" for mark in marks]
result
# Out:
# ['pass', 'pass', 'pass', 'fail', 'pass', 'pass', 'pass', 'fail']

# %%
num=[2,3,4,5,6,7,8,9,13,77,24]
num=[number for number in num if number%2==0]

# %%
num
# Out:
# [2, 4, 6, 8, 24]
