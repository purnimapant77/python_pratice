# %%
salary_amount=8600000
tax_amount=0
if salary_amount<500000:
    tax_amount+=salary_amount*0.01
elif salary_amount>500000 and salary_amount<1000000:
    tax_amount+=salary_amount*0.1
else:
    tax_amount=salary_amount*0.2

# %%
print(tax_amount)
# Out:
# 1720000.0

# %%
x=221
print("prime" if x%2==0 else "composite")
# Out:
# composite

# %%
fruits=["apple", "banana", "cherry"]
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
print(fruits)
# Out:
# ['apple', 'banana', 'cherry']

# %%
nums=[]
nums_square=[]
for iteration in range(3):
    n=int(input("Enter number:"))
    nums.append(n)
print(nums)
# Out:
# Enter number: 2
# Enter number: 3
# Enter number: 4
# [2, 3, 4]

# %%
for num in nums:
    square=num**2
    nums_square.append(square)
nums_square
# Out:
# [4, 9, 16]

# %%
#enumeration
students=["purnima", "rabi", "nidhi", "asmita"]
for index, student in enumerate(students):
    print(f"{index + 1}. {student.capitalize()}")
# Out:
# 1. Purnima
# 2. Rabi
# 3. Nidhi
# 4. Asmita

# %%
num=2
while num<5:
    print(f"number:{num}")
    num+=1
# Out:
# number:2
# number:3
# number:4
